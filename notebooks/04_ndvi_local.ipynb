# %%
import os
os.chdir(r"C:\Users\i-ryb\Desktop\fire_forecast_kurgan")
os.getcwd()
# Out:
# 'C:\\Users\\i-ryb\\Desktop\\fire_forecast_kurgan'

# %%
pip install rasterio rioxarray geopandas rasterstats numpy pandas shapely dask
# Out:
# ...
#   Obtaining dependency information for rasterio from https://files.pythonhosted.org/packages/66/d0/3818859ddbd3750d0ef5a6580a3272e81764286d943c689dd41e49b8b786/rasterio-1.4.4-cp311-cp311-win_amd64.whl.metadata
#   Using cached rasterio-1.4.4-cp311-cp311-win_amd64.whl.metadata (9.6 kB)
# ...
#   Obtaining dependency information for rioxarray from https://files.pythonhosted.org/packages/2a/2f/63d2cacc0e525f8e3398bcf32bd3620385f22cd1600834ec49d7f3597a7b/rioxarray-0.19.0-py3-none-any.whl.metadata
#   Using cached rioxarray-0.19.0-py3-none-any.whl.metadata (5.5 kB)
# ...
#   Obtaining dependency information for rasterstats from https://files.pythonhosted.org/packages/5e/0b/bd73621d2a5f87da97158c5c77a4bf31e27d60cf6bcc6ddea532043cc21d/rasterstats-0.20.0-py3-none-any.whl.metadata
#   Using cached rasterstats-0.20.0-py3-none-any.whl.metadata (4.2 kB)
# ...
